# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
   from sklearn import datasets

# %%
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=100,n_features=3)

# %%
X.shape
# Out:
# (100, 3)

# %%
y.shape
# Out:
# (100,)

# %%
plt.scatter(X[:,1],y)

# %%
for i in range(X.shape[0]):
    plt.scatter(X[:,i],y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 for i in range(X.shape[0]):
# ----> 2     plt.scatter(X[:,i],y)
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
for i in range(X.shape[0]):
    plt.figure(figsize=(5,5))
    plt.subplot(3,1,1)
    plt.scatter(X[:,i],y)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 plt.figure(figsize=(5,5))
#       3 plt.subplot(3,1,1)
# ----> 4 plt.scatter(X[:,i],y)
#       5 plt.show()
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
x_train = X[:90,:]
x_test = X[90: ,:]
y_train = y[:90]
y_test = y[90:]

# %%
x_train = np.insert(x_train,0,1,axis =1)

# %%
x_train.shape
# Out:
# (90, 4)

# %%
x_train[0]
# Out:
# array([ 1.        ,  0.29411262, -1.13178119,  0.08507912])

# %%
def personal_MLR(x_train,y_train):
    beta = np.linalg.inv(np.dot(x_train.T,x_train)).dot(x_train.T).dot(y_train)

    bias = beta[0]
    cofficient = beta[1:]

    return bias,cofficient

# %%
bias,cofficient = personal_MLR(x_train,y_train)

# %%
bias
# Out:
# -5.551115123125783e-15

# %%
cofficient
# Out:
# array([28.6833166 , 44.53527691, 37.03549338])

# %%
def predictions(x_test):
    y_pred = np.dot(x_test,cofficient) + bias
    print(y_pred.shape)

# %%
y_pred = np.insert(x_test,0,1,axis =1)
def predictr(x_test):
    

    y_pred = bias*x_test[:,0] +np.dot(intercept,x_test[:,1:])
    return y_pred

# %%
pred = predictr(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pred = predictr(x_test)
#
# Cell In[29], line 5, in predictr(x_test)
#       2 def predictr(x_test):
# ----> 5     y_pred = bias*x_test[:,0] +np.dot(intercept,x_test[:,1:])
#       6     return y_pred
#
# ValueError: shapes (3,) and (10,2) not aligned: 3 (dim 0) != 10 (dim 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test, y_train, y_test = train_test_split(X,y,test_size=0.9,random_state=2)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([28.6833166 , 44.53527691, 37.03549338])

# %%
model.intercept_
# Out:
# 1.7763568394002505e-14

# %%
pred = model.predict(x_test)

# %%
pred[0]
# Out:
# -22.061014101102717

# %%
y_train[0]
# Out:
# 136.1414522629453
